# %% [markdown]
# # Multi-Class Jet Tagging with Transformers
#
# In this tutorial, we revisit the multi-class jet-tagging task, this time using a Transformer model.
#
# Unlike the previous models, a Transformer can learn flexible relationships between different parts of the input through self-attention. In this tutorial, the input does not consist of individual particles, but of 16 high-level jet features. This means that the attention mechanism models how the different input features relate to and influence one another when forming the final prediction.
#
# In the self-attention mechanism:
#
# $$
# \text{Attention}(Q, K, V) = \text{softmax}\Big(\frac{Q K^\top}{\sqrt{d_k}}\Big) V
# $$
#
# where:
#
# - $Q$ = queries derived from the input feature representations
# - $K$ = keys derived from the input feature representations
# - $V$ = values carrying the information associated with those features
# - $d_k$ = dimension of the key vectors
#
# The matrix
#
# $$
# (Q K^\top)_{ij}
# $$
#
# captures how strongly feature $i$ is related to feature $j$. After scaling and applying the softmax function, it determines how much information from feature $j$ contributes to the updated representation of feature $i$. In this way, the Transformer can learn dependencies between features rather than treating them independently.
#
# As the previous tutorials, we train, evaluate, and compare the model step by step using the hls4ml LHC jet dataset from OpenML. This dataset contains about 830,000 simulated jets, each described by 16 high-level features and labeled as one of five classes:
#
# - quark (q),
# - gluon (g),
# - W boson (w),
# - Z boson (z),
# - top quark (t).
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/nairods/Scies4Free-FastML-tutorial/blob/main/Part2.3_Multi-Class_Classification_Transformer.ipynb)

# %% [markdown]
# # 1. Import Libraries
#
# To speed up training, switch the Colab runtime from CPU to GPU. GPUs are much better suited than CPUs for transformer training because attention and dense layers rely heavily on parallel matrix operations, which GPUs accelerate efficiently.
#
# 1. Click Runtime → Change runtime type.
#
# 2. Set Hardware accelerator to GPU.
#
# 3. Reconnect the runtime and rerun the setup cells.
#
# 4. Verify the GPU with tf.config.list_physical_devices('GPU') or  !nvidia-smi.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print("GPU detected:", gpus)
else:
    print("No GPU detected. In Colab, go to Runtime > Change runtime type > GPU.")

# %matplotlib inline
RANDOM_STATE = 42
# Out:
# GPU detected: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 2. Load Dataset

# %%
# !rm -rf /content/Scies4Free-FastML-tutorial
# !git clone https://github.com/nairods/Scies4Free-FastML-tutorial.git
DATA_PATH = "Scies4Free-FastML-tutorial/data/jet_tagging/"

train = np.load(DATA_PATH + "train.npz", allow_pickle=True)
val   = np.load(DATA_PATH + "val.npz", allow_pickle=True)
test  = np.load(DATA_PATH + "test.npz", allow_pickle=True)

X_train, y_train = train["X"], train["y"]
X_val,   y_val   = val["X"],   val["y"]
X_test,  y_test  = test["X"],  test["y"]

feature_names = ['zlogz', 'c1_b0_mmdt', 'c1_b1_mmdt', 'c1_b2_mmdt', 'c2_b1_mmdt', 'c2_b2_mmdt', 'd2_b1_mmdt', 'd2_b2_mmdt', 'd2_a1_b1_mmdt', 'd2_a1_b2_mmdt', 'm2_b1_mmdt', 'm2_b2_mmdt', 'n2_b1_mmdt', 'n2_b2_mmdt', 'mass_mmdt', 'multiplicity']
# Out:
# Cloning into 'Scies4Free-FastML-tutorial'...
# remote: Enumerating objects: 818, done.
# remote: Counting objects: 100% (226/226), done.
# remote: Compressing objects: 100% (205/205), done.
# remote: Total 818 (delta 153), reused 30 (delta 20), pack-reused 592 (from 1)
# Receiving objects: 100% (818/818), 105.12 MiB | 12.78 MiB/s, done.
# Resolving deltas: 100% (400/400), done.

# %% [markdown]
# ## Feature explanation
#
# | Feature       | Meaning                                                                                                                       |
# | ------------- | ----------------------------------------------------------------------------------------------------------------------------- |
# | zlogz         | A jet substructure variable related to how momentum is distributed among particles inside the jet.              |
# | c1_b0_mmdt    | Energy correlation feature C1 with parameter setting β=0,  mainly sensitive to the overall radiation pattern of the jet.          |
# | c1_b1_mmdt    | Energy correlation feature C1 with β=1. |
# | c1_b2_mmdt    | Energy correlation feature C1 with β=2. |
# | c2_b1_mmdt    | Energy correlation feature C2 with β=1, used to describe jet shape and prong structure.          |
# | c2_b2_mmdt    | Energy correlation feature C2 with β=2.        |
# | d2_b1_mmdt    | Energy correlation feature D2 with β=1, used to distinguish one-prong jets from two-prong or more complex jets.|
# | d2_b2_mmdt    | Energy correlation feature D2 with β=2.  |
# | d2_a1_b1_mmdt | Variant of the D2 observable with additional parameter choices. |
# | d2_a1_b2_mmdt | Another variant of the D2 observable with different parameter settings.                 |
# | m2_b1_mmdt    | Energy correlation feature M2 with β=1, used to describe finer details of jet substructure.   |
# | m2_b2_mmdt    | Energy correlation feature M2 with β=2. |
# | n2_b1_mmdt    | Energy correlation feature N2 with β=1, sensitive to the internal prong structure of a jet.      |
# | n2_b2_mmdt    | Energy correlation feature N2 with β=2.                 |
# | mass_mmdt     | Groomed jet mass after the modified mass-drop tagger (mMDT) procedure.                 |
# | multiplicity  | Number of constituents or particles reconstructed inside the jet.       |
# | target        | Jet class label: g = gluon, q = quark, t = top quark, w = W boson, z = Z boson.                       |
#
# \
# β controls how strongly the observable depends on the angular separation of particles inside the jet:
#
# smaller β is less angle-sensitive, while larger β emphasizes the jet’s geometric structure more strongly.

# %% [markdown]
# ## 3. Build the Transformer

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import (
    Input, Dense, LayerNormalization, Dropout,
    MultiHeadAttention, GlobalAveragePooling1D, Reshape
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1
import json
import os
import sys
repo_path = "/content/Scies4Free-FastML-tutorial"
sys.path.insert(0, repo_path)
from callbacks import all_callbacks

# %% [markdown]
# ### Transformer Model
#
# We use a small Transformer encoder to classify the jets. Instead of passing the 16 high-level jet features directly into a standard dense network, we treat each feature as a separate token, project it into an embedding space, and process the resulting token representations with self-attention. This allows the model to learn interactions between features before making the final classification decision.
#
# The architecture consists of two Transformer blocks, each combining multi-head self-attention, a small feed-forward network, residual connections, and layer normalization. After the feature embeddings have been contextualized in this way, they are averaged into a single jet-level representation and passed to a final dense classifier that predicts the jet class.

# %%
def transformer_block(x, embed_dim, num_heads, ff_dim, dropout=0.1):
    attn_output = MultiHeadAttention(
        num_heads=num_heads,
        key_dim=embed_dim // num_heads
    )(x, x)
    attn_output = Dropout(dropout)(attn_output)
    x = LayerNormalization(epsilon=1e-6)(x + attn_output)

    ffn = Dense(ff_dim, activation='relu',
                kernel_initializer='lecun_uniform',
                kernel_regularizer=l1(0.0001))(x)
    ffn = Dense(embed_dim,
                kernel_initializer='lecun_uniform',
                kernel_regularizer=l1(0.0001))(ffn)
    ffn = Dropout(dropout)(ffn)
    x = LayerNormalization(epsilon=1e-6)(x + ffn)
    return x

n_features = X_train.shape[1]
embed_dim = 32
num_heads = 4
ff_dim = 64

inputs = Input(shape=(n_features,), name='input_features')

# Treat each scalar feature as one token
x = Reshape((n_features, 1), name='feature_tokens')(inputs)

# Learn an embedding for each feature-token
x = Dense(embed_dim, name='feature_projection')(x)

# One or two transformer blocks
x = transformer_block(x, embed_dim=embed_dim, num_heads=num_heads, ff_dim=ff_dim, dropout=0.1)
x = transformer_block(x, embed_dim=embed_dim, num_heads=num_heads, ff_dim=ff_dim, dropout=0.1)

# Pool token representations to one vector
x = GlobalAveragePooling1D(name='token_pool')(x)

# Classification head
x = Dense(32, activation='relu',
          kernel_initializer='lecun_uniform',
          kernel_regularizer=l1(0.0001),
          name='clf_fc1')(x)

outputs = Dense(5, activation='softmax', name='output')(x)

model = Model(inputs=inputs, outputs=outputs, name='tabular_transformer')

# %% [markdown]
# ## 4. Train the model
#
# We train the neural network using the Adam optimizer and categorical cross-entropy loss. During training, the learning rate is automatically reduced if the monitored validation metric stops improving, and the best-performing model is saved in the `jet_models` directory.
#
# The network is still relatively small, so training should finish within a few minutes even on a CPU. If you have already trained the model and restarted the notebook kernel, you can set `train = False` to skip training and load the saved model instead.

# %%
train = True
if train:
    adam = Adam(learning_rate=0.0001)
    model.compile(
        optimizer=adam,
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    callbacks = all_callbacks(
        stop_patience=1000,
        lr_factor=0.5,
        lr_patience=10,
        lr_epsilon=0.000001,
        lr_cooldown=2,
        lr_minimum=0.0000001,
        outputDir='/content/Scies4Free-FastML-tutorial/jet_models/transformer',
        model_tag='transformer'
    )

    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        batch_size=1024,
        epochs=20,
        shuffle=True,
        callbacks=callbacks.callbacks,
        verbose=1
    )

    history_path = "/content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_history.json"
    os.makedirs(os.path.dirname(history_path), exist_ok=True)

    with open(history_path, "w") as f:
        json.dump(history.history, f)

else:
    with open("/content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_history.json", "r") as f:
      history = json.load(f)
    model.load_weights('/content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5')
# Out:
# Epoch 1/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4163 - loss: 1.5238
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 1: val_loss improved from None to 1.33268, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 1: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 1: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 1: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 1: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch01.weights.h5
#
# Epoch 1: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch01.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.4696 - loss: 1.4402 - val_accuracy: 0.5329 - val_loss: 1.3327 - learning_rate: 1.0000e-04
# Epoch 2/20
# 566/568 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5359 - loss: 1.3192
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 2: val_loss improved from 1.33268 to 1.26447, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 2: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 2: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 2: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 2: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch02.weights.h5
#
# Epoch 2: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch02.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5425 - loss: 1.3015 - val_accuracy: 0.5551 - val_loss: 1.2645 - learning_rate: 1.0000e-04
# Epoch 3/20
# 566/568 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5568 - loss: 1.2604
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 3: val_loss improved from 1.26447 to 1.22742, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 3: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 3: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 3: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 3: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch03.weights.h5
#
# Epoch 3: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch03.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5611 - loss: 1.2518 - val_accuracy: 0.5726 - val_loss: 1.2274 - learning_rate: 1.0000e-04
# Epoch 4/20
# 566/568 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5707 - loss: 1.2317
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 4: val_loss improved from 1.22742 to 1.20717, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 4: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 4: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 4: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 4: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch04.weights.h5
#
# Epoch 4: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch04.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5735 - loss: 1.2255 - val_accuracy: 0.5839 - val_loss: 1.2072 - learning_rate: 1.0000e-04
# Epoch 5/20
# 563/568 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5801 - loss: 1.2117
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 5: val_loss improved from 1.20717 to 1.19335, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 5: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 5: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 5: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 5: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch05.weights.h5
#
# Epoch 5: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch05.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5816 - loss: 1.2086 - val_accuracy: 0.5902 - val_loss: 1.1933 - learning_rate: 1.0000e-04
# Epoch 6/20
# 565/568 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5848 - loss: 1.1984
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 6: val_loss improved from 1.19335 to 1.18110, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 6: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 6: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 6: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 6: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch06.weights.h5
#
# Epoch 6: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch06.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5866 - loss: 1.1957 - val_accuracy: 0.5957 - val_loss: 1.1811 - learning_rate: 1.0000e-04
# Epoch 7/20
# 563/568 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5905 - loss: 1.1866
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 7: val_loss improved from 1.18110 to 1.17480, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 7: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 7: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 7: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 7: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch07.weights.h5
#
# Epoch 7: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch07.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5909 - loss: 1.1857 - val_accuracy: 0.5960 - val_loss: 1.1748 - learning_rate: 1.0000e-04
# Epoch 8/20
# 564/568 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5945 - loss: 1.1782
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 8: val_loss improved from 1.17480 to 1.16652, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 8: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 8: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 8: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 8: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch08.weights.h5
#
# Epoch 8: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch08.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5943 - loss: 1.1767 - val_accuracy: 0.6006 - val_loss: 1.1665 - learning_rate: 1.0000e-04
# Epoch 9/20
# 565/568 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5967 - loss: 1.1709
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 9: val_loss improved from 1.16652 to 1.15754, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 9: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 9: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 9: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 9: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch09.weights.h5
#
# Epoch 9: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch09.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5968 - loss: 1.1690 - val_accuracy: 0.6010 - val_loss: 1.1575 - learning_rate: 1.0000e-04
# Epoch 10/20
# 567/568 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5991 - loss: 1.1625
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 10: val_loss improved from 1.15754 to 1.15138, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 10: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 10: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 10: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 10: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch10.weights.h5
#
# Epoch 10: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch10.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5994 - loss: 1.1617 - val_accuracy: 0.6048 - val_loss: 1.1514 - learning_rate: 1.0000e-04
# Epoch 11/20
# 566/568 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6007 - loss: 1.1578
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 11: val_loss improved from 1.15138 to 1.14651, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 11: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 11: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 11: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 11: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch11.weights.h5
#
# Epoch 11: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch11.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.6013 - loss: 1.1559 - val_accuracy: 0.6040 - val_loss: 1.1465 - learning_rate: 1.0000e-04
# Epoch 12/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6014 - loss: 1.1522
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 12: val_loss improved from 1.14651 to 1.13981, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 12: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 12: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 12: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 12: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch12.weights.h5
#
# Epoch 12: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch12.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6029 - loss: 1.1499 - val_accuracy: 0.6063 - val_loss: 1.1398 - learning_rate: 1.0000e-04
# Epoch 13/20
# 564/568 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6042 - loss: 1.1438
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 13: val_loss improved from 1.13981 to 1.13383, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 13: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 13: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 13: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 13: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch13.weights.h5
#
# Epoch 13: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch13.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.6039 - loss: 1.1443 - val_accuracy: 0.6103 - val_loss: 1.1338 - learning_rate: 1.0000e-04
# Epoch 14/20
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6055 - loss: 1.1405
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 14: val_loss improved from 1.13383 to 1.12809, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 14: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 14: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 14: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 14: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch14.weights.h5
#
# Epoch 14: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch14.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6062 - loss: 1.1390 - val_accuracy: 0.6105 - val_loss: 1.1281 - learning_rate: 1.0000e-04
# Epoch 15/20
# 563/568 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6074 - loss: 1.1348
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 15: val_loss improved from 1.12809 to 1.12303, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 15: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 15: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 15: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 15: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch15.weights.h5
#
# Epoch 15: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch15.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.6073 - loss: 1.1343 - val_accuracy: 0.6125 - val_loss: 1.1230 - learning_rate: 1.0000e-04
# Epoch 16/20
# 566/568 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6086 - loss: 1.1303
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 16: val_loss improved from 1.12303 to 1.12192, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 16: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 16: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 16: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 16: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch16.weights.h5
#
# Epoch 16: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch16.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6091 - loss: 1.1296 - val_accuracy: 0.6126 - val_loss: 1.1219 - learning_rate: 1.0000e-04
# Epoch 17/20
# 562/568 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6084 - loss: 1.1282
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 17: val_loss improved from 1.12192 to 1.11530, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 17: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 17: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 17: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 17: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch17.weights.h5
#
# Epoch 17: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch17.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.6094 - loss: 1.1263 - val_accuracy: 0.6160 - val_loss: 1.1153 - learning_rate: 1.0000e-04
# Epoch 18/20
# 563/568 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6101 - loss: 1.1227
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 18: val_loss improved from 1.11530 to 1.11039, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 18: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 18: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 18: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 18: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch18.weights.h5
#
# Epoch 18: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch18.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6109 - loss: 1.1219 - val_accuracy: 0.6165 - val_loss: 1.1104 - learning_rate: 1.0000e-04
# Epoch 19/20
# 566/568 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6115 - loss: 1.1198
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 19: val_loss improved from 1.11039 to 1.10816, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 19: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 19: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 19: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 19: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch19.weights.h5
#
# Epoch 19: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch19.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6115 - loss: 1.1182 - val_accuracy: 0.6163 - val_loss: 1.1082 - learning_rate: 1.0000e-04
# Epoch 20/20
# 565/568 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6127 - loss: 1.1156
# ***callbacks***
# saving losses to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_losses.log
#
# Epoch 20: val_loss improved from 1.10816 to 1.10511, saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 20: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_best.weights.h5
#
# Epoch 20: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 20: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_last.weights.h5
#
# Epoch 20: saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch20.weights.h5
#
# Epoch 20: finished saving model to /content/Scies4Free-FastML-tutorial/jet_models/transformer/transformer_epoch20.weights.h5
#
# ***callbacks end***
#
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6126 - loss: 1.1148 - val_accuracy: 0.6180 - val_loss: 1.1051 - learning_rate: 1.0000e-04

# %% [markdown]
# ### Training History
# We plot train vs validation curves for multi-class loss and classification error.

# %%
import matplotlib.pyplot as plt
def plot_history(history, name="model", title_prefix=""):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4), sharex=True)  # 1 row, 2 cols [web:270]

    # Loss
    axes[0].plot(history["loss"], label="train loss")
    axes[0].plot(history["val_loss"], "--", label="val loss")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("Loss")
    axes[0].set_title(f"{title_prefix}{name} - Train vs Val Loss")
    axes[0].legend()

    # Accuracy
    axes[1].plot(history["accuracy"], label="train acc")
    axes[1].plot(history["val_accuracy"], "--", label="val acc")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Accuracy")
    axes[1].set_title(f"{title_prefix}{name} - Train vs Val Accuracy")
    axes[1].legend()

    plt.tight_layout()
    plt.show()

plot_history(history.history, name="jet model")

# %% [markdown]
# ## 5. Prediction Distributions
#
# For each event, the model predicts a probability for all five jet classes rather than a single binary score. This lets us inspect how confidently the network assigns events to each class.

# %%
def plot_pred_distribution_multiclass(y_true, y_score, class_names, bins=30):
    for i, class_name in enumerate(class_names):
        plt.figure(figsize=(6, 4))
        plt.hist(y_score[y_true == i, i], bins=bins, alpha=0.6, label=f"True {class_name}", color="orange")
        plt.hist(y_score[y_true != i, i], bins=bins, alpha=0.6, label=f"Not {class_name}", color="blue")
        plt.xlabel(f"Predicted probability for class '{class_name}'")
        plt.ylabel("Events")
        plt.title(f"Prediction distribution: {class_name} vs rest")
        plt.legend()
        plt.grid(True)
        plt.show()

# Predict class probabilities
y_score = model.predict(X_test)
classes = ['g', 'q', 'w', 'z', 't']
plot_pred_distribution_multiclass(y_test, y_score, classes)
# Out:
# 3891/3891 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step

# %% [markdown]
# ## 6. ROC Curve Comparison
#
# We again use ROC curves check whether the trained model is any good.

# %%
import plotting
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder

print("Accuracy: {}".format(accuracy_score(y_test, np.argmax(y_score, axis=1))))
plt.figure(figsize=(9, 9))
_ = plotting.makeRoc(tf.keras.utils.to_categorical(y_test, num_classes=len(classes)), y_score, classes)
# Out:
# Accuracy: 0.6155662650602409

# %% [markdown]
# ### When transformers are not the best models
#
# Transformers are powerful, but they are not always the best model for every task. In this tabular jet-tagging example, the standard neural network and boosted decision trees can outperform the transformer, showing that more complex architectures do not automatically lead to better results.
#
# A key reason is that this dataset contains only 16 engineered high-level jet features. In this setting, the transformer learns relationships between summary features, not between the individual particles inside a jet, so it cannot fully exploit the relational structure that makes self-attention especially useful.
#
# Transformers are usually better suited to data with rich internal structure, such as sequences, sets, or particle-level inputs. For jet physics, their strength becomes much more relevant when using constituent-level data, where the model can directly learn particle-particle interactions through attention.
