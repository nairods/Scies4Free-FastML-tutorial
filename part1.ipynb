# %% [markdown]
# <a href="https://colab.research.google.com/github/nairods/Scies4Free-FastML-tutorial/blob/main/part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone the repo fresh
# !rm -rf Scies4Free-FastML-tutorial
# !git clone https://github.com/nairods/Scies4Free-FastML-tutorial.git
# Out:
# Cloning into 'Scies4Free-FastML-tutorial'...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 75 (delta 7), reused 1 (delta 1), pack-reused 67 (from 2)
# Receiving objects: 100% (75/75), 90.31 MiB | 39.28 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
import numpy as np

DATA_PATH = "Scies4Free-FastML-tutorial/data/"

train = np.load(DATA_PATH + "train.npz", allow_pickle=True)
val   = np.load(DATA_PATH + "val.npz", allow_pickle=True)
test  = np.load(DATA_PATH + "test.npz", allow_pickle=True)

X_train, y_train = train["X"], train["y"]
X_val,   y_val   = val["X"],   val["y"]
X_test,  y_test  = test["X"],  test["y"]

print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("X_val:", X_val.shape)
print("y_val:", y_val.shape)
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)

print("\nFirst 10 validation samples:")
print(X_val[:10])

print("\nFirst 10 validation labels:")
print(y_val[:10])
# Out:
# X_train: (581000, 16)
# y_train: (581000,)
# X_val: (124500, 16)
# y_val: (124500,)
# X_test: (124500, 16)
# y_test: (124500,)
#
# First 10 validation samples:
# [[-0.7588305   0.7185985  -0.8322696  -0.7924665  -0.6877889  -0.56111795
#    0.24680977  0.4926489   0.24680977  1.1394224   1.3070527   0.8963987
#    0.9197747   0.7432118  -0.81596303  0.18941641]
#  [-0.7921125   0.6318456  -0.43221518 -0.5937844  -0.11266628 -0.33946714
#    0.74954534  0.49187306  0.74954534  0.40494922  0.334093    0.00820754
#    0.63237184  0.20697753 -0.47816306  0.74291325]
#  [ 0.6668697  -0.39974594  0.01870964 -0.21593072 -0.08618066 -0.42707935
#   -0.4199245  -0.930602   -0.4199245  -0.7378736  -0.5618141  -0.81701624
#   -0.64282596 -1.032169    0.06666352 -1.0098267 ]
#  [ 0.3815587   0.27739105  0.06001858 -0.26734495 -0.5306884  -0.5401537
#   -1.442289   -1.2255224  -1.442289   -1.2437057  -0.8688569  -0.8963009
#   -1.4095999  -1.2891966   0.08674847 -0.9637019 ]
# ...
